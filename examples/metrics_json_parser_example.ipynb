# %%
import pprint
from pathlib import Path

import numpy as np
from l2metrics.metrics_json_parser import MetricsJsonParser

# %%
json_path = Path() / '..' / 'evaluation' / 'results' / 'M12' / '2021_06_01_M12' / \
    'normalized_no_outliers' / 'sri' / 'sri_normalized_no_outliers.json'

json_parser = MetricsJsonParser(json_path)

# %%
testy = json_parser.getNormalizationDataRange("collectmineralshards_1")
pprint.pprint(testy)

# %%
testy = json_parser.getForwardTransferRatio()
# print(type(testy), testy)
json_parser.plotHist(testy)

# %%
testy = json_parser.getForwardTransferRatio(
    "collectmineralshards_1", "defeatzerglingsandbanelings_1")
# print(type(testy), testy)
# json_parser.plotLine(testy)
json_parser.plotHist(testy)

# %%
testy = json_parser.getBackwardTransferRatio()
# print(type(testy), testy)
json_parser.plotHist(testy)

# %%
testy = np.array(json_parser.getBackwardTransferRatio(
    "collectmineralshards_1", "defeatzerglingsandbanelings_1"))
# print(type(testy),testy)
testy = testy[testy != None]
# json_parser.plotHist(np.ravel(testy))
# Out:
# c:\Users\nguyeeq1\Documents\Projects\L2M\venv36\lib\site-packages\ipykernel_launcher.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-1b513109bc1c> in <module>
#       4 testy = testy[testy != None]
#       5 # json_parser.plotHist(np.ravel(testy))
# ----> 6 np.concatenate(np.ravel(testy))
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 8 has 0 dimension(s)

# %%
testy = json_parser.getForwardTransferContrast()
# print(type(testy),testy)
json_parser.plotHist(testy)

# %%
testy = json_parser.getBackwardTransferContrast()
# print(type(testy),testy)
json_parser.plotHist(testy)

# %%
testy = json_parser.getMaintenanceValMRLEP("collectmineralshards_1")
print(type(testy),testy)
# Out:
# <class 'list'> [[[-8.285607569721115], [-22.148904382470114], [-12.636952191235059]], [[-25.242778884462155], [-7.202440239043826]], [[-3.3989043824701195], [-1.0022410358565752], [-2.1414342629482084]], [[-5.054780876494024], [-12.53735059760956]], [[-2.0791832669322714], [-4.482071713147411]], [[-3.9280378486055785], [-14.591633466135459], [-15.475597609561756]], [[-3.9280378486055785], [-14.137201195219125], [-15.724601593625497]], [[-8.285607569721115], [-21.99950199203187], [-9.150896414342629]], [[-3.3989043824701195], [-1.2699203187251005], [-2.67679282868526]], [[-25.242778884462155], [-5.16683266932271]], [[-2.0791832669322714], [-5.633715139442232]], [[-5.054780876494024], [-9.437250996015937]], [[-9.007719123505979], [-4.4135956175298805], [-7.084163346613543]], [[-4.7373007968127485], [-18.97410358565737], [-25.485557768924302]], [[-7.320717131474105], [-10.71339641434263], [4.594123505976095]], [[-6.62973107569721], [-12.973107569721117]], [[-0.3672808764940241], [-0.3361553784860547]], [[-3.311752988047809], [-2.9071215139442232]], [[-7.320717131474105], [-10.532868525896415], [-18.28934262948207]], [[-4.7373007968127485], [-20.56772908366534], [-20.978585657370523]], [[-6.62973107569721], [-6.791583665338642]], [[-9.007719123505979], [-4.606573705179283], [-13.956673306772908]], [[-3.311752988047809], [-2.3842131474103594]], [[-0.3672808764940241], [-0.8590637450199212]], [[-2.969372509960161], [-7.0343625498007984], [-7.532370517928288]], [[-3.716384462151396], [-7.980577689243029], [-6.872509960159364]], [[-7.756474103585656], [-7.968127490039839], [-8.839641434262948]], [[-2.863545816733067], [-2.452689243027888], [-3.9716135458167328]], [[-3.430029880478088], [-3.635458167330677], [-3.797310756972111]], [[-26.469123505976093], [-26.680776892430277]], [[-19.876743027888452], [-21.28361553784861]], [-0.03735059760956183], [[-2.371762948207171], [-0.9897908366533859]], [-0.11205179282868372], [-3.249501992031874], [[-0.8590637450199203], [-6.212649402390439]], [[-4.63769920318725], [-5.13570717131474]], [-3.9840637450199194], [-6.959661354581674], [[0.6909860557768921], [-1.1018426294820722]], [[-3.
.974273972537226]], [[-20.385013367896953], [-20.596666754351133], [-21.468180698574244]], [[-5.682227273379473], [-5.271370699674294], [-6.7902950024631386]], [[-6.248711337124494], [-6.454139623977083], [-6.615992213618517]], [[-30.3866305486338], [-30.598283935087984]], [[-24.037028955008303], [-25.443901464968462]], [4.170337879252222], [[-5.267573762572758], [-3.8856016510189733]], [], [-0.07128628343767751], [-3.6605522687162537], [], [[-3.5591039204526442], [-8.912689577823162]], [[-7.568068063878938], [-8.066076032006428]], [-8.892309513446815], [], [-16.75416123965676], [], [[-2.3666773482301284], [-4.159506033489093]], [[-6.242486237522899], [-6.553741217602581], [-7.188701376965131]], [], [[-6.149109743498996], [-7.674259145889433], [-6.541291018399393]], [], [-13.866428516702419], [[-24.01212855660193], [-26.0913118235342]], [-3.0218979849831458], [], [-2.1572747471651876], [[-16.007142498433637], [-19.1694930960432], [-18.17347715978822]], [[-14.17073811596352], [-16.916007040266308], [-20.675967199628857]], [[-21.194276316104123], [-21.26897751132325], [-23.136507391801338]], [[-20.945272332040382], [-21.65493368662205], [-23.323260379849145]], [[-29.054459233892764], [-26.564419393255314]], [[-4.495661411975149], [-3.736199260580726]], [[-2.142573762572759], [-5.205322766556822]], [], [-1.948001264174076], [[-6.335498342763401], [-8.551633800930732]], [[-7.530717466269378], [-6.52225133081121]], [-0.6147429512718379], [], [], [], [-1.6933946904688941], [], [[-20.4348141647097], [-20.870571136821255], [-21.754535280247552]], [1.8174130401471036], [[-16.276413576463376], [-20.97013867606497], [-20.97013867606497]], [[-16.232837879252223], [-19.787369751762178], [-21.493047042598835]], [[-18.98589296659516], [-18.027227627949742], [-20.031709699662887]], [[-18.674637986515478], [-19.483900934722648], [-13.221450735519461]], [], [-19.475735712611737], [], [-4.741509352745083], [[-15.943322862396567], [-18.1594583205639]], [[-19.9534554091327], [-25.089162580447443], [-25.089162580447443]], [[-16.852187404229237], [-17.960255133312902]], [[-19.81650321789764], [-18.12950122586577], [-20.12153309837573]], [[-0.6909238047808763], [-4.513134960159363]], [[-4.139628984063745], [-2.7078560756972108]], [-3.163145736382205], [], [-3.0962927137603433], [], [[2.9223586423536636], [-0 ...

# %%
testy = json_parser.getRecoveryTimes("collectmineralshards_1")
# print(type(testy),testy)
arr = np.array(testy)
json_parser.plotHist(np.concatenate(np.ravel(arr[arr != None])))
# Out:
# c:\Users\nguyeeq1\Documents\Projects\L2M\venv36\lib\site-packages\ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
testy = json_parser.getPerfRecoveryRate()
# print(type(testy),testy)
json_parser.plotHist(testy)

# %%
testy = json_parser.getPerfMaintenanceMRLEP()
# print(type(testy),testy)
json_parser.plotHist(testy)

# %%
testy = json_parser.getPerfMaintenanceMRTLP()
# print(type(testy),testy)
json_parser.plotHist(testy)

# %%
testy = json_parser.getSTERelPerf()
# print(type(testy),testy)
json_parser.plotHist(testy)

# %%
testy = json_parser.getSampleEfficiency()
# print(type(testy),testy)
json_parser.plotHist(testy)

# %%
testy = json_parser.getRunID()
print(type(testy),testy)

# %%
testy = json_parser.getComplexity()
print(type(testy),testy)

# %%
testy = json_parser.getMetricsColumn()
print(type(testy),testy)

# %%
testy = json_parser.getScenarioType()
print(type(testy),testy)

# %%
testy = json_parser.getDifficulty()
print(type(testy),testy)

# %%
testy1= json_parser.getMinMax()
print(type(testy1),testy1)
# print(type(testy2),testy2)

# %%
testy1 = json_parser.getNumLXEX()
print(type(testy1),testy1)
# print(type(testy2),testy2)

# %%
# pprint.pprint(json_parser.df2dict(json_parser.df))
# for key in json_parser.df2dict(json_parser.df).keys():
#     print([(k,type(k)) for k in key if k == k])
# for col in json_parser.df.columns:
#     print(col)
# pprint.pprint(json_parser.df.to_dict())
